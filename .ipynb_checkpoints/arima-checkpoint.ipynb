# %% [markdown]
# ## Importações

# %%
import warnings 
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from datetime import datetime
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Necessário instalar o pmdarima no terminal com o comando: pip install pmdarima
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
from pmdarima.arima import auto_arima

# %% [markdown]
# ## Carregar dados

# %% [markdown]
# Os arquivos CSV com os dados das APAC foram carregados e então alguns registros foram visualizados para verificar se a importação, criação do index e o parse da data ocorreu de forma correta. Também foram demonstradas algumas informações das séries, a fim de verificar as mesmas foram carregadas por completo e se existe algum valor importado fora do padrão ou nulo.

# %%
# Converter a coluna de competencia para data
date_parse = lambda dates: datetime.strptime(dates, '%Y-%m-%d')

# Carregar os dados
base_filgrastim = pd.read_csv('./dados/filgrastim_300mcg.csv', parse_dates=['competencia'], index_col='competencia', date_parser=date_parse)
base_golimumabe = pd.read_csv('./dados/golimumabe_50mg.csv', parse_dates=['competencia'], index_col='competencia', date_parser=date_parse)
base_imiglucerase = pd.read_csv('./dados/imiglucerase_400u.csv', parse_dates=['competencia'], index_col='competencia', date_parser=date_parse)

# %%
# Visualização das cinco primeiras linhas
base_filgrastim.head()
# Out:
#              qtd_dispensada
# competencia
# 2019-01-01             3660
# 2019-02-01             3198
# 2019-03-01             1638
# 2019-04-01             1880
# 2019-05-01             4761

# %%
# Visualização das cinco primeiras linhas
base_golimumabe.head()
# Out:
#              qtd_dispensada
# competencia
# 2019-01-01             6411
# 2019-02-01             7169
# 2019-03-01             7133
# 2019-04-01             7325
# 2019-05-01             7397

# %%
# Visualização das cinco primeiras linhas
base_imiglucerase.head()
# Out:
#              qtd_dispensada
# competencia
# 2019-01-01             6152
# 2019-02-01             6487
# 2019-03-01             5784
# 2019-04-01             5804
# 2019-05-01             5630

# %%
# Verificar se existe algum valor nulo
base_filgrastim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 36 entries, 2019-01-01 to 2021-12-01
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   qtd_dispensada  36 non-null     int64
# dtypes: int64(1)
# memory usage: 576.0 bytes

# %%
# Verificar se existe algum valor nulo
base_golimumabe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 36 entries, 2019-01-01 to 2021-12-01
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   qtd_dispensada  36 non-null     int64
# dtypes: int64(1)
# memory usage: 576.0 bytes

# %%
# Verificar se existe algum valor nulo
base_imiglucerase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 36 entries, 2019-01-01 to 2021-12-01
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   qtd_dispensada  36 non-null     int64
# dtypes: int64(1)
# memory usage: 576.0 bytes

# %% [markdown]
# ## Visualizar série histórica

# %% [markdown]
# Abaixo é apresentada as séries históricas dos medicamentos incluídos nesse estudo, cada um contendo 36 meses de registro de dispensação. Tendo em vista que os medicamentos são distribuídos aos estados pelo Ministério da Saúde trimestralmente, e que a dispensação ao paciente pode ocorrer de forma antecipada em até três meses, foi plotado uma série histórica suavizada, agregando os dados por trimestre.

# %%
# Criar as séries temporais
ts_filgrastim = base_filgrastim['qtd_dispensada']
ts_golimumabe = base_golimumabe['qtd_dispensada']
ts_imiglucerase = base_imiglucerase['qtd_dispensada']

ts_filgrastim_trimestre = base_filgrastim.resample('Q').sum()
ts_golimumabe_trimestre = base_golimumabe.resample('Q').sum()
ts_imiglucerase_trimestre = base_imiglucerase.resample('Q').sum()

# Plotar os gráficos das séries temporais   
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(18, 6))
fig.tight_layout()

ax[0,0].plot(ts_filgrastim)
ax[0,0].set_title("Filgrastim - série histórica")

ax[0,1].plot(ts_filgrastim_trimestre)
ax[0,1].set_title("Filgrastim - por trimestre")

ax[1,0].plot(ts_golimumabe)
ax[1,0].set_title("Golimumabe - série histórica")

ax[1,1].plot(ts_golimumabe_trimestre)
ax[1,1].set_title("Golimumabe - por trimestre")

ax[2,0].plot(ts_imiglucerase)
ax[2,0].set_title("Imiglucerase - série histórica")

ax[2,1].plot(ts_imiglucerase_trimestre)
ax[2,1].set_title("Imiglucerase - por trimestre")

plt.show()

# %% [markdown]
# ## Arima

# %% [markdown]
# ### Decomposição

# %% [markdown]
# O Arima permite decompocor uma série temporal para que possa ser analisado quatro padrões: tendência, variações cíclicas, sazonalidade e variações irregulares.

# %%
# Preparação para decompor a série temporal
decoposicao_filgratim = seasonal_decompose(base_filgrastim)
decoposicao_golimumabe = seasonal_decompose(base_golimumabe)
decoposicao_imiglucerase = seasonal_decompose(base_imiglucerase)

# Obter a tendência da série temporal
tendencia_filgratim = decoposicao_filgratim.trend
tendencia_golimumabe = decoposicao_golimumabe.trend
tendencia_imiglucerase = decoposicao_imiglucerase.trend

# Obter a sozonalidade da série temporal
sazonal_filgratim = decoposicao_filgratim.seasonal
sazonal_golimumabe = decoposicao_golimumabe.seasonal
sazonal_imiglucerase = decoposicao_imiglucerase.seasonal

# Obter o resíduo da série temporal
resid_filgratim = decoposicao_filgratim.resid
resid_golimumabe = decoposicao_golimumabe.resid
resid_imiglucerase = decoposicao_imiglucerase.resid

# Plotar os gráficos das decomposições
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(18, 9))
fig.tight_layout()

ax[0,0].plot(tendencia_filgratim)
ax[0,0].set_title("Filgrastim - Tendência")

ax[0,1].plot(sazonal_filgratim)
ax[0,1].set_title("Filgrastim - Sazonalidade")

ax[0,2].plot(resid_filgratim)
ax[0,2].set_title("Filgrastim - Resíduo")

ax[1,0].plot(tendencia_golimumabe)
ax[1,0].set_title("Golimumabe - Tendência")

ax[1,1].plot(sazonal_golimumabe)
ax[1,1].set_title("Golimumabe - Sazonalidade")

ax[1,2].plot(resid_golimumabe)
ax[1,2].set_title("Golimumabe - Resíduo")

ax[2,0].plot(tendencia_imiglucerase)
ax[2,0].set_title("Imiglucerase - Tendência")

ax[2,1].plot(sazonal_imiglucerase)
ax[2,1].set_title("Imiglucerase - Sazonalidade")

ax[2,2].plot(resid_imiglucerase)
ax[2,2].set_title("Imiglucerase - Resíduo")
# Out:
# Text(0.5, 1.0, 'Imiglucerase - Resíduo')

# %% [markdown]
# ### Estacionalidade
# Por meio do Teste de Dickey-Fuller Aumentado (ADF) foi verificado se as séries temporais são estacionárias ou não. Caso o ADF retorne o p-value inferior ao nível de confiança de 0.05 será considerado que a série é estacionária.
# Verificou-se que apenas o medicamento Imiglucerase 400U possui uma série estacionária. Assim, o modelo Arima para esse medicamento possuirá o termo de diferenciação (d) igual a 0. Para os demais medicamentos será preciso realizar a decomposição para identificar o valor d.

# %%
# Teste de Dickey-Fuller Aumentado (ADF) para verificar se a série temporal é estacionária
adf_filgrastim = adfuller(base_filgrastim)
print('Teste ADF')
print('Teste Estatístico: {:.4f}'.format(adf_filgrastim[0]))
print('p-value: {:.4f}'.format(adf_filgrastim[1]))
print('Valores Críticos:')
for key, value in adf_filgrastim[4].items():
	print('\t{}: {:.4f}'.format(key, value))
if adf_filgrastim[1] > 0.05:
    print("Hipotese nula aceita. Série não estacionária.")
else:
    print("Hipotese nula rejeitada. Série estacionária.")
# Out:
# Teste ADF
# Teste Estatístico: -2.6991
# p-value: 0.0742
# Valores Críticos:
# 	1%: -3.6327
# 	5%: -2.9485
# 	10%: -2.6130
# Hipotese nula aceita. Série não estacionária.

# %%
# Teste de Dickey-Fuller Aumentado (ADF) para verificar se a série temporal é estacionária
adf_golimumabe = adfuller(base_golimumabe)
print('Teste ADF')
print('Teste Estatístico: {:.4f}'.format(adf_golimumabe[0]))
print('p-value: {:.4f}'.format(adf_golimumabe[1]))
print('Valores Críticos:')
for key, value in adf_golimumabe[4].items():
	print('\t{}: {:.4f}'.format(key, value))
if adf_golimumabe[1] > 0.05:
    print("Hipotese nula aceita. Série não estacionária.")
else:
    print("Hipotese nula rejeitada. Série estacionária.")
# Out:
# Teste ADF
# Teste Estatístico: 1.3644
# p-value: 0.9969
# Valores Críticos:
# 	1%: -3.7112
# 	5%: -2.9812
# 	10%: -2.6301
# Hipotese nula aceita. Série não estacionária.

# %%
# Teste de Dickey-Fuller Aumentado (ADF) para verificar se a série temporal é estacionária
adf_imiglucese = adfuller(base_imiglucerase)
print('Teste ADF')
print('Teste Estatístico: {:.4f}'.format(adf_imiglucese[0]))
print('p-value: {:.4f}'.format(adf_imiglucese[1]))
print('Valores Críticos:')
for key, value in adf_imiglucese[4].items():
	print('\t{}: {:.4f}'.format(key, value))
if adf_imiglucese[1] > 0.05:
    print("Hipotese nula aceita. Série não estacionária.")
else:
    print("Hipotese nula rejeitada. Série estacionária.")
# Out:
# Teste ADF
# Teste Estatístico: -4.6588
# p-value: 0.0001
# Valores Críticos:
# 	1%: -3.6327
# 	5%: -2.9485
# 	10%: -2.6130
# Hipotese nula rejeitada. Série estacionária.

# %% [markdown]
# ### Diferenciação

# %% [markdown]
# Como foi verificado que as séries temporais para os medicamentos Filgrastim 300mcg e Golimumabe 50mg não são estacionárias, será necessário realizar a diferenciação para remover a tendência e sazonalidade dos dados originais.
# Foi verificado que apenas uma diferenciação foi suficiente para tornar as séries estacionárias, sendo que este achado foi corroborado com a realização do teste ADF. Assim, ambos os medicamentos terão o valor d igual a 1.

# %%
# Série original
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 6))
fig.tight_layout()

axes[0, 0].plot(base_filgrastim.qtd_dispensada); axes[0, 0].set_title('Série temporal original - Filgrastim')
plot_acf(base_filgrastim.qtd_dispensada, ax=axes[0, 1])

# 1a diferenciação
axes[1, 0].plot(base_filgrastim.qtd_dispensada.diff()); axes[1, 0].set_title('1a ordem de diferenciação - Filgrastim')
plot_acf(base_filgrastim.qtd_dispensada.diff().dropna(), ax=axes[1, 1])

plt.show()

# %%
# Teste de Dickey-Fuller Aumentado (ADF) para verificar se a série temporal ficou estacionária após a diferenciação
adf_imiglucese = adfuller(base_imiglucerase.qtd_dispensada.diff().dropna())
print('Teste ADF')
print('Teste Estatístico: {:.4f}'.format(adf_imiglucese[0]))
print('p-value: {:.4f}'.format(adf_imiglucese[1]))
print('Valores Críticos:')
for key, value in adf_imiglucese[4].items():
	print('\t{}: {:.4f}'.format(key, value))
if adf_imiglucese[1] > 0.05:
    print("Hipotese nula aceita. Série não estacionária.")
else:
    print("Hipotese nula rejeitada. Série estacionária.")
# Out:
# Teste ADF
# Teste Estatístico: -9.8379
# p-value: 0.0000
# Valores Críticos:
# 	1%: -3.6392
# 	5%: -2.9512
# 	10%: -2.6144
# Hipotese nula rejeitada. Série estacionária.

# %%
# Série original
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 6))
fig.tight_layout()

axes[0, 0].plot(base_golimumabe.qtd_dispensada); axes[0, 0].set_title('Série temporal original - Golimumabe')
plot_acf(base_golimumabe.qtd_dispensada, ax=axes[0, 1])

# 1a diferenciação
axes[1, 0].plot(base_golimumabe.qtd_dispensada.diff()); axes[1, 0].set_title('1a ordem de diferenciação - Golimumabe')
plot_acf(base_golimumabe.qtd_dispensada.diff().dropna(), ax=axes[1, 1])

plt.show()

# %%
# Teste de Dickey-Fuller Aumentado (ADF) para verificar se a série temporal ficou estacionária após a diferenciação
adf_imiglucese = adfuller(base_imiglucerase.qtd_dispensada.diff().dropna())
print('Teste ADF')
print('Teste Estatístico: {:.4f}'.format(adf_imiglucese[0]))
print('p-value: {:.4f}'.format(adf_imiglucese[1]))
print('Valores Críticos:')
for key, value in adf_imiglucese[4].items():
	print('\t{}: {:.4f}'.format(key, value))
if adf_imiglucese[1] > 0.05:
    print("Hipotese nula aceita. Série não estacionária.")
else:
    print("Hipotese nula rejeitada. Série estacionária.")
# Out:
# Teste ADF
# Teste Estatístico: -9.8379
# p-value: 0.0000
# Valores Críticos:
# 	1%: -3.6392
# 	5%: -2.9512
# 	10%: -2.6144
# Hipotese nula rejeitada. Série estacionária.

# %% [markdown]
# Para identificar o melhor valor para o parâmetro P foi utilizada a atocorrelação parcial (PACF). Pela avaliação visual identificou que os melhores valores são 0, 0 e 1 para o Filgrastim 300mcg, Golimumabe 50mg e Imiglucerase 400U, respectivamente.

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 9))
fig.tight_layout()

# PACF Filgrastim
axes[0, 0].plot(base_filgrastim.qtd_dispensada.diff()); axes[0, 0].set_title('1a ordem de diferenciação - Filgrastim')
plot_pacf(base_filgrastim.qtd_dispensada.diff().dropna(), ax=axes[0, 1])

# PACF Golimumabe
axes[1, 0].plot(base_golimumabe.qtd_dispensada.diff()); axes[1, 0].set_title('1a ordem de diferenciação - Golimumabe')
plot_pacf(base_golimumabe.qtd_dispensada.diff().dropna(), ax=axes[1, 1])

# PACF Imiglucerase
axes[2, 0].plot(base_imiglucerase.qtd_dispensada); axes[2, 0].set_title('Série temporal original - Imiglucerase')
plot_pacf(base_golimumabe.qtd_dispensada.dropna(), ax=axes[2, 1])

plt.show()

# %% [markdown]
# Por fim, restou identificar o melhor valor para o parâmetro Q e para isso foi utilizado o ACF. Após análise verificou-se que o valor Q deve ser 1 para todos os medicamentos.
# Como o ACF ainda não tinha sido obtido para o Imiglucerase, o mesmo foi plotado abaixo.

# %%
# ACF para o Imiglucerase
fig, axes = plt.subplots(1, 2, figsize=(15, 3))
fig.tight_layout()

axes[0].plot(base_imiglucerase.qtd_dispensada); axes[0].set_title('Série temporal original - Imiglucerase')
plot_acf(base_imiglucerase.qtd_dispensada.dropna(), ax=axes[1])

plt.show()

# %% [markdown]
# Dessa forma, foram obtidos os seguintes valores iniciais para realizar as previsões no Arima:
# | Medicamento                       | p | d | q |
# |-----------------------------------|---|---|---|
# | Filgrastim 300mcg injetável       | 0 | 1 | 1 |
# | Golimumabe 50mg solução injetável | 0 | 1 | 1 |
# | Imiglucerase 400U injetável       | 1 | 0 | 1 |

# %% [markdown]
# ### Auto arima

# %% [markdown]
# Utilizar o auto_arima para identificar os melhores parâmetros para o Arima.

# %%
# Utilizar o auto_arima para identificar os melhores parametros para o Arima. A escolha será pelo menor AIC.
stepwise_model_filgrastim = auto_arima(base_filgrastim, error_action='ignore', start_p=1, start_q=1, start_d=0, start_P=0, max_p=6, max_q=6, m=12, seasonal=True, trace=True, stepwise=False)

#exibir o sumário com as métricas encontradas
stepwise_model_filgrastim.summary()
# Out:
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=566.429, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=568.270, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=570.148, Time=0.09 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=568.251, Time=0.02 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=570.164, Time=0.08 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=572.152, Time=0.07 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=570.152, Time=0.05 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=572.152, Time=0.05 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=574.152, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=564.364, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=566.356, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=566.356, Time=0.07 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=568.344, Time=0.19 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=563.740, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=565.694, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,3)(0,0,2)[12] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,1,3)(2,0,0)[12] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,1,4)(0,0,0)[12] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,4)(0,0,1)[12] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,1,4)(1,0,0)[12] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,1,5)(0,0,0)[12] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=566.535, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=568.397, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=570.332, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=568.365, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=570.359, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=572.313, Time=0.21 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=570.331, Time=0.09 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=572.331, Time=0.16 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=574.330, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=569.724, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=564.741, Time=0.13 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=573.103, Time=0.28 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=571.100, Time=0.11 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=566.730, Time=0.30 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(1,1,4)(0,0,0)[12] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=565.293, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=567.211, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=569.158, Time=0.16 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=567.210, Time=0.07 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=569.219, Time=0.11 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=569.140, Time=0.26 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=566.731, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=567.934, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=570.739, Time=0.36 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=568.063, Time=0.17 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=570.068, Time=0.39 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=566.596, Time=0.04 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=568.593, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=570.550, Time=0.17 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=568.598, Time=0.08 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=570.561, Time=0.16 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=570.570, Time=0.24 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=567.724, Time=0.08 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=570.595, Time=0.12 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=570.600, Time=0.13 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=568.497, Time=0.08 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=570.483, Time=0.17 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=570.607, Time=0.08 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[12] intercept
# Total fit time: 15.078 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   36
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -277.870
# Date:                Tue, 28 Mar 2023   AIC                            563.740
# Time:                        09:43:33   BIC                            569.961
# Sample:                    01-01-2019   HQIC                           565.887
#                          - 12-01-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     64.5517     61.337      1.052      0.293     -55.667     184.770
# ma.L1         -0.3999      0.341     -1.172      0.241      -1.069       0.269
# ma.L2         -0.3056      0.190     -1.608      0.108      -0.678       0.067
# sigma2      4.531e+05   8.12e+04      5.581      0.000    2.94e+05    6.12e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                31.77
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.13   Skew:                             1.45
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Utilizar o auto_arima para identificar os melhores parametros para o Arima. A escolha será pelo menor AIC.
stepwise_model_golimumabe = auto_arima(base_golimumabe, error_action='ignore', start_p=1, start_q=1, start_d=0, start_P=0, max_p=6, max_q=6, m=12, seasonal=True, trace=True, stepwise=False)

#exibir o sumário com as métricas encontradas
stepwise_model_golimumabe.summary()
# Out:
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=393.109, Time=0.01 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=395.106, Time=0.05 sec
#  ARIMA(0,1,0)(0,1,2)[12]             : AIC=397.070, Time=0.24 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=395.106, Time=0.05 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,0)(1,1,2)[12]             : AIC=inf, Time=0.40 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=397.071, Time=0.08 sec
#  ARIMA(0,1,0)(2,1,1)[12]             : AIC=399.103, Time=0.13 sec
#  ARIMA(0,1,0)(2,1,2)[12]             : AIC=inf, Time=0.55 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=392.300, Time=0.03 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=394.198, Time=0.08 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=inf, Time=0.64 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=inf, Time=0.13 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=inf, Time=0.13 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=inf, Time=0.54 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=inf, Time=0.63 sec
#  ARIMA(0,1,1)(2,1,1)[12]             : AIC=inf, Time=0.62 sec
#  ARIMA(0,1,1)(2,1,2)[12]             : AIC=inf, Time=1.19 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=inf, Time=0.03 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,2)(0,1,2)[12]             : AIC=inf, Time=0.43 sec
#  ARIMA(0,1,2)(1,1,0)[12]             : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,2)(1,1,1)[12]             : AIC=inf, Time=0.18 sec
#  ARIMA(0,1,2)(1,1,2)[12]             : AIC=inf, Time=0.68 sec
#  ARIMA(0,1,2)(2,1,0)[12]             : AIC=inf, Time=0.74 sec
#  ARIMA(0,1,2)(2,1,1)[12]             : AIC=inf, Time=0.93 sec
#  ARIMA(0,1,3)(0,1,0)[12]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,3)(0,1,1)[12]             : AIC=inf, Time=0.23 sec
#  ARIMA(0,1,3)(0,1,2)[12]             : AIC=inf, Time=1.06 sec
#  ARIMA(0,1,3)(1,1,0)[12]             : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,3)(1,1,1)[12]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,1,3)(2,1,0)[12]             : AIC=inf, Time=0.96 sec
#  ARIMA(0,1,4)(0,1,0)[12]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,4)(0,1,1)[12]             : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,4)(1,1,0)[12]             : AIC=inf, Time=0.16 sec
#  ARIMA(0,1,5)(0,1,0)[12]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=394.661, Time=0.02 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=396.655, Time=0.07 sec
#  ARIMA(1,1,0)(0,1,2)[12]             : AIC=398.657, Time=0.17 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=396.678, Time=0.04 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.68 sec
#  ARIMA(1,1,0)(1,1,2)[12]             : AIC=400.657, Time=0.52 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=398.657, Time=0.12 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=400.657, Time=0.16 sec
#  ARIMA(1,1,0)(2,1,2)[12]             : AIC=402.657, Time=0.16 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,1,1)(0,1,2)[12]             : AIC=inf, Time=0.54 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=inf, Time=0.13 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=inf, Time=0.27 sec
#  ARIMA(1,1,1)(1,1,2)[12]             : AIC=inf, Time=0.80 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=inf, Time=0.54 sec
#  ARIMA(1,1,1)(2,1,1)[12]             : AIC=inf, Time=1.01 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=inf, Time=0.06 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=inf, Time=0.14 sec
#  ARIMA(1,1,2)(0,1,2)[12]             : AIC=inf, Time=0.82 sec
#  ARIMA(1,1,2)(1,1,0)[12]             : AIC=inf, Time=0.28 sec
#  ARIMA(1,1,2)(1,1,1)[12]             : AIC=inf, Time=0.19 sec
#  ARIMA(1,1,2)(2,1,0)[12]             : AIC=inf, Time=0.81 sec
#  ARIMA(1,1,3)(0,1,0)[12]             : AIC=388.264, Time=0.15 sec
#  ARIMA(1,1,3)(0,1,1)[12]             : AIC=inf, Time=0.35 sec
#  ARIMA(1,1,3)(1,1,0)[12]             : AIC=391.735, Time=0.31 sec
#  ARIMA(1,1,4)(0,1,0)[12]             : AIC=inf, Time=0.09 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=389.444, Time=0.02 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=391.425, Time=0.04 sec
#  ARIMA(2,1,0)(0,1,2)[12]             : AIC=393.424, Time=0.18 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=391.426, Time=0.07 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=393.426, Time=0.06 sec
#  ARIMA(2,1,0)(1,1,2)[12]             : AIC=inf, Time=0.88 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=393.424, Time=0.18 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=0.89 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=inf, Time=0.09 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=inf, Time=0.21 sec
#  ARIMA(2,1,1)(0,1,2)[12]             : AIC=inf, Time=0.89 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=inf, Time=0.23 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=394.043, Time=0.25 sec
#  ARIMA(2,1,1)(2,1,0)[12]             : AIC=inf, Time=0.92 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=inf, Time=0.10 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=inf, Time=0.19 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=inf, Time=0.18 sec
#  ARIMA(2,1,3)(0,1,0)[12]             : AIC=inf, Time=0.15 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=391.529, Time=0.02 sec
#  ARIMA(3,1,0)(0,1,1)[12]             : AIC=393.323, Time=0.11 sec
#  ARIMA(3,1,0)(0,1,2)[12]             : AIC=395.320, Time=0.47 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=393.324, Time=0.15 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=0.24 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=395.505, Time=0.27 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=inf, Time=0.10 sec
#  ARIMA(3,1,1)(0,1,1)[12]             : AIC=inf, Time=0.19 sec
#  ARIMA(3,1,1)(1,1,0)[12]             : AIC=inf, Time=0.27 sec
#  ARIMA(3,1,2)(0,1,0)[12]             : AIC=inf, Time=0.12 sec
#  ARIMA(4,1,0)(0,1,0)[12]             : AIC=390.287, Time=0.07 sec
#  ARIMA(4,1,0)(0,1,1)[12]             : AIC=392.165, Time=0.13 sec
#  ARIMA(4,1,0)(1,1,0)[12]             : AIC=392.154, Time=0.19 sec
#  ARIMA(4,1,1)(0,1,0)[12]             : AIC=391.041, Time=0.12 sec
#  ARIMA(5,1,0)(0,1,0)[12]             : AIC=391.851, Time=0.11 sec
#
# Best model:  ARIMA(1,1,3)(0,1,0)[12]
# Total fit time: 29.064 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                   36
# Model:             SARIMAX(1, 1, 3)x(0, 1, [], 12)   Log Likelihood                -189.132
# Date:                             Mon, 27 Mar 2023   AIC                            388.264
# Time:                                     22:11:40   BIC                            393.942
# Sample:                                 01-01-2019   HQIC                           389.692
#                                       - 12-01-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6651      0.304     -2.186      0.029      -1.261      -0.069
# ma.L1          1.1679      0.449      2.602      0.009       0.288       2.047
# ma.L2         -0.5911      0.333     -1.773      0.076      -1.245       0.063
# ma.L3         -0.7817      0.308     -2.540      0.011      -1.385      -0.178
# sigma2      5.568e+05   1.18e-06   4.73e+11      0.000    5.57e+05    5.57e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                 1.60
# Prob(Q):                              0.73   Prob(JB):                         0.45
# Heteroskedasticity (H):               5.80   Skew:                            -0.64
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.96e+27. Standard errors may be unstable.
# """

# %%
# Utilizar o auto_arima para identificar os melhores parametros para o Arima. A escolha será pelo menor AIC.
stepwise_model_imiglucerase = auto_arima(base_imiglucerase, error_action='ignore', start_p=1, start_q=1, start_d=0, start_P=0, max_p=6, max_q=6, m=12, seasonal=True, trace=True, stepwise=False)

#exibir o sumário com as métricas encontradas
stepwise_model_imiglucerase.summary()
# Out:
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=556.192, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=558.086, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=559.583, Time=0.06 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=558.101, Time=0.02 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=561.583, Time=0.09 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=559.580, Time=0.06 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=561.558, Time=0.19 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=563.580, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=547.798, Time=0.47 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=547.934, Time=0.10 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,1,3)(0,0,2)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=548.854, Time=0.17 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,1,3)(2,0,0)[12] intercept   : AIC=549.615, Time=0.41 sec
#  ARIMA(0,1,4)(0,0,0)[12] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,4)(0,0,1)[12] intercept   : AIC=550.148, Time=0.24 sec
#  ARIMA(0,1,4)(1,0,0)[12] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(0,1,5)(0,0,0)[12] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=550.558, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=552.423, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=553.792, Time=0.13 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=552.461, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=553.907, Time=0.16 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=550.134, Time=0.41 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=549.791, Time=0.44 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=550.452, Time=0.21 sec
#  ARIMA(1,1,4)(0,0,0)[12] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=550.292, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=552.209, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=553.269, Time=0.18 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=552.235, Time=0.04 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=553.451, Time=0.19 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=551.507, Time=0.04 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=553.436, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=554.784, Time=0.23 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=553.449, Time=0.09 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=554.933, Time=0.24 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=550.623, Time=0.18 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=551.146, Time=0.05 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=553.105, Time=0.09 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=553.109, Time=0.11 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=552.968, Time=0.05 sec
#
# Best model:  ARIMA(0,1,1)(2,0,1)[12] intercept
# Total fit time: 18.326 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   36
# Model:             SARIMAX(0, 1, 1)x(2, 0, 1, 12)   Log Likelihood                -267.899
# Date:                            Mon, 27 Mar 2023   AIC                            547.798
# Time:                                    22:11:58   BIC                            557.130
# Sample:                                01-01-2019   HQIC                           551.019
#                                      - 12-01-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    -18.3842     26.299     -0.699      0.485     -69.929      33.161
# ma.L1         -0.9735      0.754     -1.291      0.197      -2.452       0.505
# ar.S.L12      -0.5996      1.727     -0.347      0.728      -3.985       2.785
# ar.S.L24      -0.1449      0.665     -0.218      0.827      -1.448       1.158
# ma.S.L12       0.7035      1.901      0.370      0.711      -3.022       4.429
# sigma2      2.458e+05   1.96e+05      1.253      0.210   -1.39e+05     6.3e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.80
# Prob(Q):                              0.94   Prob(JB):                         0.67
# Heteroskedasticity (H):               0.77   Skew:                            -0.31
# Prob(H) (two-sided):                  0.66   Kurtosis:                         3.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## Criar as bases de treino (80%) e teste (20%).

# %%
train_filgrastim = base_filgrastim[:28]
test_filgrastim = base_filgrastim[28:]
#train_filgrastim
#test_filgrastim

# %%
train_golimumabe = base_golimumabe[:28]
test_golimumabe = base_golimumabe[28:]
#train_golimumabe.shape
#test_golimumabe.shape

# %%
train_imiglucerase = base_imiglucerase[:28]
test_imiglucerase = base_imiglucerase[28:]
#train_imiglucerase.shape
#test_imiglucerase.shape

# %% [markdown]
# ## Treinar e criar o modelo Arima

# %% [markdown]
# Treinar os modelos criados pelo auto_arima, fazer as previsões e plotar os resultados.

# %%
stepwise_model_filgrastim.fit(train_filgrastim)
prediction_filgrastim = pd.DataFrame(stepwise_model_filgrastim.predict(n_periods=8), index=base_filgrastim.index)
prediction_filgrastim.columns = ['qtd_dispensada']
plt.figure(figsize=(8,5))
plt.plot(train_filgrastim, label='Training')
plt.plot(test_filgrastim, label='Test')
plt.plot(prediction_filgrastim, label='Predictions')
plt.legend()

# %%
stepwise_model_golimumabe.fit(train_golimumabe)
prediction_golimumabe = pd.DataFrame(stepwise_model_golimumabe.predict(n_periods=8), index=base_golimumabe.index)
prediction_golimumabe.columns = ['qtd_dispensada']

plt.figure(figsize=(8,5))
plt.plot(train_golimumabe, label='Training')
plt.plot(test_golimumabe, label='Test')
plt.plot(prediction_golimumabe, label='Predictions')
plt.legend()

# %%
stepwise_model_imiglucerase.fit(train_imiglucerase)
prediction_imiglucerase = pd.DataFrame(stepwise_model_imiglucerase.predict(n_periods=8), index=base_imiglucerase.index)
prediction_imiglucerase.columns = ['qtd_dispensada']

plt.figure(figsize=(8,5))
plt.plot(train_imiglucerase, label='Training')
plt.plot(test_imiglucerase, label='Test')
plt.plot(prediction_imiglucerase, label='Predictions')
plt.legend()

# %% [markdown]
# O modelo Arima foi criado, testado e plotado.

# %%
model_filgrastim = ARIMA(train_filgrastim, order=(0, 1, 1))  
fitted_filgrastim = model.fit()  

# Forecast
fc_filgrastim, se_filgrastim, conf_filgrastim = fitted_filgrastim.forecast(15, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc_filgrastim, index=test_filgrastim.index)
lower_series = pd.Series(conf[:, 0], index=test_filgrastim.index)
upper_series = pd.Series(conf[:, 1], index=test_filgrastim.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='Treino')
plt.plot(test, label='Teste')
plt.plot(fc_series, label='Previsão')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Previsão x real')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/8b/qc075dx54rz2n4b34bdnlkz00000gn/T/ipykernel_937/3841574522.py in <module>
# ----> 1 model_filgrastim = ARIMA(train_filgrastim, order=(0, 1, 1))
#       2 fitted_filgrastim = model.fit()
#       3
#       4 # Forecast
#       5 fc_filgrastim, se_filgrastim, conf_filgrastim = fitted_filgrastim.forecast(15, alpha=0.05)  # 95% conf
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.
